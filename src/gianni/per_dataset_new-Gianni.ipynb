# %%
import numpy as np
import pandas as pd

# %%
df_socioec = pd.read_csv('dataset_olimpiadi_indicatori_ita.csv')
df_countries = pd.read_csv('Olympic_Country_Profiles.csv')
pop_wb = pd.read_csv('API_SP.POP.TOTL_DS2_EN_csv_v2_3107.csv', skiprows=4)

# %%
df_socioec['Anno'] = df_socioec[('Anno')].astype(int)
df_socioec
# Out:
#         Edizione_Olimpiadi  ID_Edizione  Anno  \
# 0     1964 Summer Olympics         16.0  1964
# 1     1964 Summer Olympics         16.0  1964
# 2     1964 Summer Olympics         16.0  1964
# 3     1964 Summer Olympics         16.0  1964
# 4     1964 Summer Olympics         16.0  1964
# ...                    ...          ...   ...
# 3363  2020 Summer Olympics         61.0  2020
# 3364  2020 Summer Olympics         61.0  2020
# 3365  2020 Summer Olympics         61.0  2020
# 3366  2020 Summer Olympics         61.0  2020
# 3367  2020 Summer Olympics         61.0  2020
#
#                                      Nazione Codice_NOC  Medaglie_Oro  \
# 0                              United States        USA          36.0
# 1                               Soviet Union        RUS          30.0
# 2                                      Japan        JPN          16.0
# 3                                    Germany        GER          10.0
# ...

# %%
df_socioec['Nazione'].unique()
# Out:
# array(['United States', 'Soviet Union', 'Japan', 'Germany', 'Italy',
#        'Hungary', 'Poland', 'Australia', 'Czechoslovakia',
#        'Great Britain', 'Bulgaria', 'Finland', 'New Zealand', 'Romania',
#        'Netherlands', 'Türkiye', 'Sweden', 'Denmark', 'Yugoslavia',
#        'Belgium', 'France', 'Canada', 'Switzerland', 'Ethiopia', 'India',
#        'The Bahamas', 'Republic of Korea', 'Trinidad and Tobago',
#        'Tunisia', 'Argentina', 'Cuba', 'Pakistan', 'Philippines',
#        'Islamic Republic of Iran', 'Brazil', 'Ghana', 'Ireland', 'Kenya',
#        'Mexico', 'Nigeria', 'Uruguay', 'East Germany', 'West Germany',
#        'Norway', 'Venezuela', 'Austria', 'Mongolia', 'Uganda', 'Cameroon',
#        'Jamaica', 'Chinese Taipei', 'Greece',
#        "Democratic People's Republic of Korea", 'Colombia', 'Lebanon',
#        'Niger', 'Spain', 'Portugal', 'Bermuda', 'Puerto Rico', 'Thailand',
#        'Zimbabwe', 'United Republic of Tanzania', 'Guyana',
# ...

# %%
mapping_varianti = {
    'Iran, Islamic Republic of': 'Iran',
    'Islamic Republic of Iran': 'Iran',
    'Tanzania, United Republic of': 'Tanzania',
    'United Republic of Tanzania': 'Tanzania',
    'Moldova, Republic of': 'Moldova',
    'Republic of Moldova': 'Moldova',
    'Venezuela, Bolivarian Republic of': 'Venezuela',
    'Viet Nam': 'Vietnam',
    'Congo, Democratic Republic of the': 'Democratic Republic of the Congo',
    'The Bahamas': 'Bahamas',
    'Korea, Republic of': 'South Korea',
    'Republic of Korea': 'South Korea',
    "Korea, Democratic People's Republic of": 'North Korea',
    "Democratic People's Republic of Korea": 'North Korea',
    "People's Republic of China": 'China',
    'Hong Kong, China': 'Hong Kong',
    'United States of America': 'United States',
    'Kingdom of Saudi Arabia': 'Saudi Arabia',
    'Palestine, State of': 'Palestine',
    'Virgin Islands (U.S.)': 'United States Virgin Islands',
    'United States Virgin Islands': 'United States Virgin Islands',
    'Micronesia, Federated States of': 'Federated States of Micronesia',
    'Bolivia, Plurinational State of': 'Bolivia',
    'Netherlands, Kingdom of the': 'Netherlands',
    'Guinea Bissau': 'Guinea-Bissau',
    'The Gambia': 'Gambia',
    'São Tomé and Príncipe': 'Sao Tome and Principe'
}

# %%
country_mapping = {
    **mapping_varianti
}

# %%
df_socioec['Nazione'] = df_socioec['Nazione'].replace(country_mapping)

# %%
df_countries['country'] = df_countries['country'].replace(country_mapping)

# %%
noc_to_country = df_socioec.groupby('Codice_NOC')['Nazione'].unique()
noc_multi_country = noc_to_country[noc_to_country.apply(len) > 1]
noc_multi_country
# Out:
# Codice_NOC
# BRN          [Bahrain, Brunei Darussalam]
# RUS    [Soviet Union, Russian Federation]
# Name: Nazione, dtype: object

# %%
df_socioec.loc[df_socioec['Nazione'] == 'Brunei Darussalam', 'Codice_NOC'] = 'BRU'
df_socioec.loc[df_socioec['Nazione'] == 'Soviet Union', 'Codice_NOC'] = 'URS'

# %%
noc_to_country = df_socioec.groupby('Codice_NOC')['Nazione'].unique()
noc_multi_country = noc_to_country[noc_to_country.apply(len) > 1]
noc_multi_country
# Out:
# Series([], Name: Nazione, dtype: object)

# %%
df_socioec['Nazione'].unique()
# Out:
# array(['United States', 'Soviet Union', 'Japan', 'Germany', 'Italy',
#        'Hungary', 'Poland', 'Australia', 'Czechoslovakia',
#        'Great Britain', 'Bulgaria', 'Finland', 'New Zealand', 'Romania',
#        'Netherlands', 'Türkiye', 'Sweden', 'Denmark', 'Yugoslavia',
#        'Belgium', 'France', 'Canada', 'Switzerland', 'Ethiopia', 'India',
#        'Bahamas', 'South Korea', 'Trinidad and Tobago', 'Tunisia',
#        'Argentina', 'Cuba', 'Pakistan', 'Philippines', 'Iran', 'Brazil',
#        'Ghana', 'Ireland', 'Kenya', 'Mexico', 'Nigeria', 'Uruguay',
#        'East Germany', 'West Germany', 'Norway', 'Venezuela', 'Austria',
#        'Mongolia', 'Uganda', 'Cameroon', 'Jamaica', 'Chinese Taipei',
#        'Greece', 'North Korea', 'Colombia', 'Lebanon', 'Niger', 'Spain',
#        'Portugal', 'Bermuda', 'Puerto Rico', 'Thailand', 'Zimbabwe',
#        'Tanzania', 'Guyana', 'China', 'Morocco', "Côte d'Ivoire", 'Egypt',
# ...

# %%
paesi_socioec = set(df_socioec['Nazione'].unique())
paesi_countries = set(df_countries['country'].unique())

# %%
solo_in_socioec = paesi_socioec - paesi_countries
print("Solo in df_socioec:", solo_in_socioec)

solo_in_countries = paesi_countries - paesi_socioec
print("Solo in df_countries:", solo_in_countries)
# Out:
# Solo in df_socioec: {'French Polynesia', 'Greenland', 'Macao', 'New Caledonia'}
# Solo in df_countries: {'South Vietnam', 'Russian Olympic Committee', 'Individual Neutral Athletes', 'North Yemen', 'Newfoundland', 'Bohemia', 'South Yemen', 'United Arab Republic', 'Mixed team', 'Australasia', 'Refugee Olympic Team', 'West Indies Federation', 'Crete', 'Cook Islands', 'Unknown', 'Saar', 'British Virgin Islands', 'North Borneo', 'Rhodesia', 'Korea Team', 'Malaya'}

# %%
paesi_comuni = paesi_socioec & paesi_countries

noc_socioec = (
    df_socioec[df_socioec['Nazione'].isin(paesi_comuni)]
    .groupby('Nazione')['Codice_NOC']
    .unique()
)

noc_countries = (
    df_countries[df_countries['country'].isin(paesi_comuni)]
    .groupby('country')['noc']
    .unique()
)

confronto_noc = pd.concat([noc_socioec, noc_countries], axis=1, keys=['noc_socioec', 'noc_countries'])
confronto_noc
# Out:
#                noc_socioec noc_countries
# Afghanistan          [AFG]         [AFG]
# Albania              [ALB]         [ALB]
# Algeria         [ALG, DZA]         [ALG]
# American Samoa       [ASM]         [ASA]
# Andorra              [AND]         [AND]
# ...                    ...           ...
# West Germany         [FRG]         [FRG]
# Yemen                [YEM]         [YEM]
# Yugoslavia           [YUG]         [YUG]
# Zambia               [ZAM]         [ZAM]
# Zimbabwe             [ZIM]         [ZIM]
#
# [214 rows x 2 columns]

# %%
confronto_noc.to_csv("codici.csv", index=False)

# %%
df_socioec['Codice_NOC'] = df_socioec.groupby('Nazione')['Codice_NOC'].transform('first')

# %%
paesi_socioec2  = set(df_socioec['Nazione'].unique())
paesi_countries2 = set(df_countries['country'].unique())

# %%
paesi_comuni2 = paesi_socioec2 & paesi_countries2

noc_socioec = (
    df_socioec[df_socioec['Nazione'].isin(paesi_comuni2)]
    .groupby('Nazione')['Codice_NOC']
    .unique()
)

noc_countries = (
    df_countries[df_countries['country'].isin(paesi_comuni2)]
    .groupby('country')['noc']
    .unique()
)

confronto_noc2 = pd.concat([noc_socioec, noc_countries], axis=1, keys=['noc_socioec', 'noc_countries'])
confronto_noc2
# Out:
#                noc_socioec noc_countries
# Afghanistan          [AFG]         [AFG]
# Albania              [ALB]         [ALB]
# Algeria              [ALG]         [ALG]
# American Samoa       [ASM]         [ASA]
# Andorra              [AND]         [AND]
# ...                    ...           ...
# West Germany         [FRG]         [FRG]
# Yemen                [YEM]         [YEM]
# Yugoslavia           [YUG]         [YUG]
# Zambia               [ZAM]         [ZAM]
# Zimbabwe             [ZIM]         [ZIM]
#
# [214 rows x 2 columns]

# %%
confronto_noc2.to_csv('codici2.csv', index=False)

# %%
year_cols = [c for c in pop_wb.columns if c.isdigit()]

pop_long = pop_wb.melt(
    id_vars=['Country Code',  'Country Name'],
    value_vars=year_cols,
    var_name='year',
    value_name='population_wb'
)
pop_long['year'] = pop_long['year'].astype(int)
pop_long['population_wb'] = pd.to_numeric(pop_long['population_wb'], errors='coerce')

# %%
pop_long
# Out:
#       Country Code                 Country Name  year  population_wb
# 0              ABW                        Aruba  1960        54922.0
# 1              AFE  Africa Eastern and Southern  1960    130075728.0
# 2              AFG                  Afghanistan  1960      9035043.0
# 3              AFW   Africa Western and Central  1960     97630925.0
# 4              AGO                       Angola  1960      5231654.0
# ...            ...                          ...   ...            ...
# 17485          XKX                       Kosovo  2025      1576876.0
# 17486          YEM                  Yemen, Rep.  2025     41773878.0
# 17487          ZAF                 South Africa  2025     64747319.0
# 17488          ZMB                       Zambia  2025     21913874.0
# 17489          ZWE                     Zimbabwe  2025     16950795.0
#
# [17490 rows x 4 columns]

# %%
pop_long['Country Name'] = pop_long['Country Name'].replace(country_mapping)

# %%
paesi_socioec3  = set(df_socioec['Nazione'].unique())
paesi_pop3 = set(pop_long['Country Name'].unique())

# %%
solo_in_socioec3 = paesi_socioec3 - paesi_pop3
print("Solo in df_socioec:", solo_in_socioec3)

solo_in_pop3 = paesi_pop3 - paesi_socioec3
print("Solo in df_countries:", solo_in_pop3)
# Out:
# Solo in df_socioec: {'Saint Lucia', 'Saint Kitts and Nevis', 'Kyrgyzstan', 'Serbia and Montenegro', 'Soviet Union', 'Great Britain', 'North Korea', 'Saint Vincent and the Grenadines', 'West Germany', 'Democratic Republic of the Congo', 'Iran', 'Yugoslavia', 'East Germany', 'South Korea', 'Bahamas', 'Independent Olympic Athletes', 'Yemen', 'Federated States of Micronesia', 'Congo', 'Gambia', 'Macao', 'Czechoslovakia', 'Türkiye', 'Chinese Taipei', 'Slovakia', 'Palestine', 'Venezuela', "Lao People's Democratic Republic", 'Somalia', 'Egypt', 'Netherlands Antilles', "Côte d'Ivoire", 'ROC', 'Puerto Rico', 'Hong Kong', 'Unified Team'}
# ...

# %%
mapping_varianti2 = {
    'Egypt, Arab Rep.': 'Egypt',
    'Lao PDR': "Lao People's Democratic Republic",
    'Gambia, The': 'Gambia',
    'Turkiye': 'Türkiye',
    'United Kingdom': 'Great Britain',
    "Korea, Dem. People's Rep.": 'North Korea',
    'Korea, Rep.': 'South Korea',
    'Bahamas, The': 'Bahamas',
    'Somalia, Fed. Rep.': 'Somalia',
    'Congo, Dem. Rep.': 'Democratic Republic of the Congo',
    'Hong Kong SAR, China': 'Hong Kong',
    'Iran, Islamic Rep.': 'Iran',
    'Congo, Rep.': 'Congo',
    'Slovak Republic': 'Slovakia',
    'St. Vincent and the Grenadines': 'Saint Vincent and the Grenadines',
    'St. Lucia': 'Saint Lucia',
    'Kyrgyz Republic': 'Kyrgyzstan',
    'Venezuela, RB': 'Venezuela',
    "Cote d'Ivoire": "Côte d'Ivoire",
    'Puerto Rico (US)': 'Puerto Rico',
    'Macao SAR, China': 'Macao',
    'St. Kitts and Nevis': 'Saint Kitts and Nevis',
    'Yemen, Rep.': 'Yemen',
    'Micronesia, Fed. Sts.': 'Federated States of Micronesia',
}

# %%
country_mapping2 = {
    **mapping_varianti2
}

# %%
pop_long['Country Name'] = pop_long['Country Name'].replace(country_mapping2)

# %%
paesi_socioec4 = set(df_socioec['Nazione'].unique())
paesi_pop4 = set(pop_long['Country Name'].unique())

# %%
solo_in_socioec4 = paesi_socioec4 - paesi_pop4
print("Solo in df_socioec:", solo_in_socioec4)

solo_in_pop4 = paesi_pop4 - paesi_socioec4
print("Solo in df_countries:", solo_in_pop4)
# Out:
# Solo in df_socioec: {'Independent Olympic Athletes', 'Netherlands Antilles', 'Yugoslavia', 'Soviet Union', 'ROC', 'East Germany', 'Czechoslovakia', 'Serbia and Montenegro', 'Chinese Taipei', 'Unified Team', 'West Germany', 'Palestine'}
# ...

# %%
paesi_comuni4 = paesi_socioec4 & paesi_pop4

noc_socioec = (
    df_socioec[df_socioec['Nazione'].isin(paesi_comuni4)]
    .groupby('Nazione')['Codice_NOC']
    .unique()
)

noc_pop = (
   pop_long[pop_long['Country Name'].isin(paesi_comuni4)]
    .groupby('Country Name')['Country Code']
    .unique()
)

confronto_noc4 = pd.concat([noc_socioec, noc_pop], axis=1, keys=['noc_socioec', 'noc_pop'])
confronto_noc4
# Out:
#                noc_socioec noc_pop
# Afghanistan          [AFG]   [AFG]
# Albania              [ALB]   [ALB]
# Algeria              [ALG]   [DZA]
# American Samoa       [ASM]   [ASM]
# Andorra              [AND]   [AND]
# ...                    ...     ...
# Venezuela            [VEN]   [VEN]
# Vietnam              [VIE]   [VNM]
# Yemen                [YEM]   [YEM]
# Zambia               [ZAM]   [ZMB]
# Zimbabwe             [ZIM]   [ZWE]
#
# [206 rows x 2 columns]

# %%
pop_long.groupby('Country Name')['Country Code'].nunique().sort_values(ascending=False).head()
# Out:
# Country Name
# Afghanistan                    1
# Africa Eastern and Southern    1
# Africa Western and Central     1
# Albania                        1
# Algeria                        1
# Name: Country Code, dtype: int64

# %%
def get_population_for_olympic_year(country_name, olympic_year, pop_data, years_back=4):
    target_years = list(range(olympic_year - years_back, olympic_year))
    subset = pop_data[
        (pop_data['Country Name'] == country_name) &
        (pop_data['year'].isin(target_years))
    ]['population_wb']
    if subset.dropna().empty:
        return np.nan
    return subset.mean(skipna=True)


nan_mask = df_socioec['Popolazione_Totale'].isna()

df_socioec.loc[nan_mask, 'Popolazione_Totale'] = df_socioec[nan_mask].apply(
    lambda row: get_population_for_olympic_year(
        country_name=row['Nazione'],
        olympic_year=int(row['Anno']),
        pop_data=pop_long
    ),
    axis=1
)

# %%
df_socioec[df_socioec['Popolazione_Totale'].isna()].groupby('Nazione').size().sort_values(ascending=False)
# Out:
# Nazione
# Chinese Taipei                  10
# Czechoslovakia                   7
# Palestine                        7
# Yugoslavia                       7
# East Germany                     5
# West Germany                     5
# Serbia and Montenegro            3
# Independent Olympic Athletes     2
# Netherlands Antilles             1
# ROC                              1
# Unified Team                     1
# dtype: int64

# %%
duplicati = df_socioec[df_socioec.duplicated(keep=False)]
print(f"Righe duplicate: {len(duplicati)}")
duplicati
# Out:
# Righe duplicate: 0
# Empty DataFrame
# Columns: [Edizione_Olimpiadi, ID_Edizione, Anno, Nazione, Codice_NOC, Medaglie_Oro, Medaglie_Argento, Medaglie_Bronzo, Totale_Medaglie, Paese_Ospitante, Citta_Ospitante, Precipitazioni_Medie_mm, Superficie_Totale_km2, Investimenti_Diretti_Esteri_perc_PIL, Densita_Popolazione, Inflazione_Prezzi_Consumo, Spesa_Militare_Valuta_Locale, Spesa_Militare_perc_PIL, Spesa_Pubblica_Consumi_USD, Spesa_Nazionale_Lorda_Valuta_Locale, Interscambio_Commerciale_perc_PIL, Valore_Aggiunto_Industria_perc_PIL, Valore_Aggiunto_Servizi_Valuta_Locale, Valore_Aggiunto_Servizi_perc_PIL, Inflazione_Deflatore_PIL, PIL_Assoluto_USD, PIL_Valuta_Locale, Crescita_PIL_perc_annua, PIL_Pro_Capite_USD, RNL_Valuta_Locale, RNL_Pro_Capite_USD, Iscrizioni_Scuola_Primaria_perc, Tasso_Mortalita_Neonatale, Tasso_Mortalita_Infantile, Aspettativa_di_Vita, Popolazione_Eta_Lavorativa_perc, Crescita_Demografica_perc, Popolazione_Totale, Popolazione_Urbana, Tasso_Urbanizzazione_perc]
# ...

# %%
df_socioec.to_csv("dataset_indicatori_definitivo.csv", index=False)

# %% [markdown]
# ## Correzioni aggiuntive dopo il fix del collega (Russia/Germania)
#
# Il dataset `dataset_indicatori_definitivo_4.csv` prodotto dal collega ha risolto correttamente il problema delle righe duplicate per Russia/URSS (EUN 1992, ROC 2020) e per Germania, mappando i codici NOC sui codici ISO usati dagli indicatori World Bank.
#
# Un controllo sistematico su tutte le altre nazioni storicamente divise o nate nel periodo 1964-2020 mostra che **lo stesso meccanismo di fondo** (indicatori socioeconomici agganciati per nome-paese su tutta la serie storica, indipendentemente da quale fosse l'identità olimpica realmente in vigore quell'anno — vedi Cella 16 di preparazione dati) genera lo stesso tipo di righe fittizie anche per:
#
# - **Cecoslovacchia → Cechia + Slovacchia** (1964-1992)
# - **Jugoslavia → Bosnia-Erzegovina, Croazia, Macedonia del Nord, Montenegro, Slovenia, Serbia** (1964-1992)
# - **Serbia e Montenegro (SCG) → Serbia + Montenegro separate** (1996-2004)
#
# e un problema diverso ma imparentato (stessa nazione, codice NOC incoerente nel tempo, senza duplicati nello stesso anno) per:
#
# - **Trinidad and Tobago**: codice TTO/TRI alternato
# - **Egitto**: codice UAR (1964-1968) poi EGY
#
# Le celle seguenti applicano le stesse correzioni già validate per Russia/Germania a questi casi, partendo dal dataset del collega.

# %%
import pandas as pd

df = pd.read_csv('dataset_indicatori_definitivo_4.csv')
print("Shape dataset di partenza (dataset_indicatori_definitivo_4.csv):", df.shape)
print("Duplicati Codice_NOC+Anno di partenza:", df.duplicated(subset=['Codice_NOC', 'Anno'], keep=False).sum())
# Out:
# Shape dataset di partenza (dataset_indicatori_definitivo_4.csv): (3126, 40)
# Duplicati Codice_NOC+Anno di partenza: 0

# %% [markdown]
# ### Categoria A — righe fittizie per federazioni sciolte
#
# Per ciascuna federazione con dati reali (Cecoslovacchia, Jugoslavia, Serbia e Montenegro) si individuano le righe dei Paesi 'figli' che non esistevano ancora come Comitati Olimpici indipendenti in quegli anni. **Per sicurezza si rimuovono solo le righe a 0 medaglie**: se un Paese figlio ha già medaglie reali in un anno del range (es. Croazia e Slovenia dal 1992, primo anno di indipendenza olimpica), quella riga viene conservata automaticamente, perché il filtro `Totale_Medaglie == 0` non la intercetta.

# %%
federazioni = [
    {'genitore': 'TCH', 'figli': ['CZE', 'SVK'], 'anno_min': 1964, 'anno_max': 1992},
    {'genitore': 'YUG', 'figli': ['BIH', 'CRO', 'MKD', 'MNE', 'SLO', 'SRB'], 'anno_min': 1964, 'anno_max': 1992},
    {'genitore': 'SCG', 'figli': ['SRB', 'MNE'], 'anno_min': 1996, 'anno_max': 2004},
]

righe_da_rimuovere = pd.Index([])
for f in federazioni:
    mask = (
        df['Codice_NOC'].isin(f['figli'])
        & (df['Anno'] >= f['anno_min'])
        & (df['Anno'] <= f['anno_max'])
        & (df['Totale_Medaglie'] == 0)
    )
    idx = df[mask].index
    print(f"{f['genitore']} -> {f['figli']} ({f['anno_min']}-{f['anno_max']}), righe fittizie a 0 medaglie: {len(idx)}")
    righe_da_rimuovere = righe_da_rimuovere.union(idx)

print()
print("Totale righe fittizie individuate:", len(righe_da_rimuovere))
# Out:
# TCH -> ['CZE', 'SVK'] (1964-1992), righe fittizie a 0 medaglie: 16
# YUG -> ['BIH', 'CRO', 'MKD', 'MNE', 'SLO', 'SRB'] (1964-1992), righe fittizie a 0 medaglie: 46
# SCG -> ['SRB', 'MNE'] (1996-2004), righe fittizie a 0 medaglie: 6
#
# Totale righe fittizie individuate: 68

# %%
# Controllo di sicurezza: nessuna riga con medaglie reali deve finire tra quelle da rimuovere
check = df.loc[righe_da_rimuovere]
print("Righe da rimuovere con Totale_Medaglie != 0 (deve essere 0):", (check['Totale_Medaglie'] != 0).sum())

# Caso di verifica esplicito: Croazia e Slovenia 1992 devono restare nel dataset
verifica_1992 = df[(df['Codice_NOC'].isin(['CRO', 'SLO'])) & (df['Anno'] == 1992)]
print()
print("Croazia/Slovenia 1992 (devono restare, con medaglie reali):")
print(verifica_1992[['Nazione', 'Codice_NOC', 'Anno', 'Totale_Medaglie']].to_string(index=False))
print("Presenti tra le righe da rimuovere?", verifica_1992.index.isin(righe_da_rimuovere).any())
# Out:
# Righe da rimuovere con Totale_Medaglie != 0 (deve essere 0): 0
#
# Croazia/Slovenia 1992 (devono restare, con medaglie reali):
#  Nazione Codice_NOC  Anno  Totale_Medaglie
#  Croatia        CRO  1992                3
# Slovenia        SLO  1992                2
# Presenti tra le righe da rimuovere? False

# %%
df_puliti = df.drop(index=righe_da_rimuovere).reset_index(drop=True)
print("Shape dopo la rimozione della Categoria A:", df_puliti.shape,
      f"(rimosse {len(righe_da_rimuovere)} righe fittizie)")
# Out:
# Shape dopo la rimozione della Categoria A: (3058, 40) (rimosse 68 righe fittizie)

# %% [markdown]
# ### Categoria B — stessa nazione, codice NOC incoerente nel tempo
#
# Trinidad and Tobago ed Egitto non hanno righe duplicate nello stesso anno, ma la loro serie storica è spezzata su due codici NOC diversi (nessuna sovrapposizione di anni tra i due codici, quindi qui non si rimuove nulla: si rinomina il codice più vecchio su quello più recente, per avere una serie continua utile al calcolo dei lag).

# %%
unificazioni = {'TRI': 'TTO', 'UAR': 'EGY'}

print("Righe per codice prima dell'unificazione:")
for old_code in unificazioni:
    print(f"  {old_code}: {(df_puliti['Codice_NOC'] == old_code).sum()} righe")

df_puliti['Codice_NOC'] = df_puliti['Codice_NOC'].replace(unificazioni)

print()
print("Serie storica dopo l'unificazione:")
for country, code in [('Trinidad and Tobago', 'TTO'), ('Egypt', 'EGY')]:
    sub = df_puliti[df_puliti['Codice_NOC'] == code][['Anno', 'Totale_Medaglie']].sort_values('Anno')
    print(f"\n{country} ({code}):")
    print(sub.to_string(index=False))
# Out:
# Righe per codice prima dell'unificazione:
#   TRI: 7 righe
#   UAR: 2 righe
#
# Serie storica dopo l'unificazione:
#
# Trinidad and Tobago (TTO):
#  Anno  Totale_Medaglie
#  1964                3
#  1968                0
#  1972                0
#  1976                1
#  1980                0
#  1984                0
#  1988                0
#  1992                0
#  1996                2
#  2000                2
#  2004                1
#  2008                2
#  2012                4
#  2016                1
#  2020                0
#
# Egypt (EGY):
#  Anno  Totale_Medaglie
#  1964                0
#  1968                0
#  1972                0
#  1976                0
#  1980                0
#  1984                1
#  1988                0
#  1992                0
#  1996                0
#  2000                0
#  2004                5
#  2008                2
#  2012                4
#  2016                3
#  2020                6

# %% [markdown]
# ### Verifica finale e salvataggio

# %%
dup_finali = df_puliti.duplicated(subset=['Codice_NOC', 'Anno'], keep=False)
print("Duplicati Codice_NOC+Anno dopo tutte le correzioni:", dup_finali.sum())

print("Somma Totale_Medaglie originale (dataset_indicatori_definitivo_4):", df['Totale_Medaglie'].sum())
print("Somma Totale_Medaglie dopo le correzioni:", df_puliti['Totale_Medaglie'].sum())
print("(deve restare identica: le righe rimosse erano tutte a 0 medaglie)")

print()
print("Shape finale:", df_puliti.shape, "vs shape di partenza:", df.shape)
# Out:
# Duplicati Codice_NOC+Anno dopo tutte le correzioni: 0
# Somma Totale_Medaglie originale (dataset_indicatori_definitivo_4): 11782
# Somma Totale_Medaglie dopo le correzioni: 11782
# (deve restare identica: le righe rimosse erano tutte a 0 medaglie)
#
# Shape finale: (3058, 40) vs shape di partenza: (3126, 40)

# %%
df_puliti.to_csv('dataset_indicatori_definitivo_5.csv', index=False)
print("Salvato: dataset_indicatori_definitivo_5.csv")
print("Righe:", len(df_puliti), "| Colonne:", len(df_puliti.columns))
# Out:
# Salvato: dataset_indicatori_definitivo_5.csv
# Righe: 3058 | Colonne: 40

# %% [markdown]
# ### Riepilogo correzioni
#
# | Correzione | Righe coinvolte |
# |---|---|
# | Cecoslovacchia → Cechia/Slovacchia (righe fittizie rimosse) | 16 |
# | Jugoslavia → Bosnia-Erz./Croazia/Macedonia del Nord/Montenegro/Slovenia/Serbia (righe fittizie rimosse) | 46 |
# | Serbia e Montenegro → Serbia/Montenegro separate (righe fittizie rimosse) | 6 |
# | **Totale righe fittizie rimosse** | **68** |
# | Trinidad and Tobago (TRI → TTO, unificazione codice) | 7 |
# | Egitto (UAR → EGY, unificazione codice) | 2 |
#
# Dataset finale: **3.058 righe**, 0 duplicati su Codice_NOC+Anno, somma delle medaglie invariata rispetto al dataset di partenza (11.782) — a conferma che non è stata toccata nessuna medaglia reale, solo righe fittizie e codici NOC incoerenti.
#
# File prodotto: `dataset_indicatori_definitivo_5.csv`.
